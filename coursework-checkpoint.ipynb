# %%
import pandas as pd # Importing pandas library
import matplotlib.pyplot as plt

covid = pd.read_csv (r"C:\Users\chinw\Downloads\covid.csv") # loading dataset
# Below is dataset
covid
# Out:
#         location      continent    date  cases_per_M  deaths_per_M  \
# 0    Afghanistan           Asia  May-20      390.641         6.602
# 1        Albania         Europe  May-20      394.398        11.120
# 2        Algeria         Africa  May-20      214.202        14.868
# 3      Argentina  South America  May-20      372.823        11.904
# 4      Australia        Oceania  May-20      281.374         4.000
# ..           ...            ...     ...          ...           ...
# 520   Uzbekistan           Asia  Feb-21      228.539         0.358
# 521    Venezuela  South America  Feb-21     1569.633        19.482
# 522        Yemen           Asia  Feb-21       29.907         3.420
# 523       Zambia         Africa  Feb-21     3676.739        44.060
# 524     Zimbabwe         Africa  Feb-21     1788.679        82.823
#
#      stringency_index  population_density  median_age  aged_65_older  \
# 0               84.26              54.422        18.6          2.581
# 1               86.11             104.871        38.0         13.188
# 2               76.85              17.348        29.1          6.211
# 3               90.74              16.177        31.9         11.198
# 4               63.43               3.202        37.9         15.504
# ..                ...                 ...         ...            ...
# 520             37.04              76.134        28.2          4.469
# 521             84.26              36.253        29.0          6.614
# 522             25.00              53.508        20.3          2.922
# 523             36.11              22.995        17.7          2.480
# 524             87.96              42.729        19.6          2.822
#
#      aged_70_older  ...  med_R  max_R  workplace_closures  contact_tracing  \
# 0            1.337  ...  1.405   1.50                None          Limited
# 1            8.643  ...  1.040   1.45              Strict    Comprehensive
# 2            3.857  ...  1.110   2.02              Strict    Comprehensive
# 3            7.441  ...  1.345   1.83              Strict    Comprehensive
# 4           10.129  ...  0.785   2.40              Strict    Comprehensive
# ..             ...  ...    ...    ...                 ...              ...
# 520          2.873  ...  0.930   1.23                Some    Comprehensive
# 521          3.915  ...  1.000   1.18              Strict             None
# 522          1.583  ...  1.090   1.72                None             None
# 523          1.542  ...  1.170   1.39              Strict    Comprehensive
# 524          1.882  ...  0.940   1.47                Some          Limited
#
#      testing_policy cancel_public_events facial_coverings  \
# 0     IfSymptomatic           NoMeasures           Strict
# 1     IfSymptomatic                  Ban           Strict
# 2     IfSymptomatic                Avoid           Strict
# 3     IfSymptomatic                  Ban           Strict
# 4     IfSymptomatic                  Ban      Recommended
# ..              ...                  ...              ...
# 520   IfSymptomatic                Avoid           Strict
# 521          Public                  Ban           Strict
# 522            None           NoMeasures         NoPolicy
# 523   IfSymptomatic                Avoid           Strict
# 524   IfSymptomatic                  Ban           Strict
#
#     international_travel_controls school_closures mortality
# 0                       Screening         Minimal       Low
# 1                      Quarantine            Some       Low
# 2                   BorderClosure            Some       Low
# 3                   BorderClosure        Required       Low
# 4                   BorderClosure            Some       Low
# ..                            ...             ...       ...
# 520                           Ban            Some       Low
# 521                 BorderClosure        Required       Low
# 522                 BorderClosure         Minimal       Low
# 523                    Quarantine            Some       Low
# 524                    Quarantine            Some      High
#
# [525 rows x 23 columns]

# %%
# See first 5 rows
covid.head()
# Out:
#       location      continent    date  cases_per_M  deaths_per_M  \
# 0  Afghanistan           Asia  May-20      390.641         6.602
# 1      Albania         Europe  May-20      394.398        11.120
# 2      Algeria         Africa  May-20      214.202        14.868
# 3    Argentina  South America  May-20      372.823        11.904
# 4    Australia        Oceania  May-20      281.374         4.000
#
#    stringency_index  population_density  median_age  aged_65_older  \
# 0             84.26              54.422        18.6          2.581
# 1             86.11             104.871        38.0         13.188
# 2             76.85              17.348        29.1          6.211
# 3             90.74              16.177        31.9         11.198
# 4             63.43               3.202        37.9         15.504
#
#    aged_70_older  ...  med_R  max_R  workplace_closures  contact_tracing  \
# 0          1.337  ...  1.405   1.50                None          Limited
# 1          8.643  ...  1.040   1.45              Strict    Comprehensive
# 2          3.857  ...  1.110   2.02              Strict    Comprehensive
# 3          7.441  ...  1.345   1.83              Strict    Comprehensive
# 4         10.129  ...  0.785   2.40              Strict    Comprehensive
#
#    testing_policy cancel_public_events facial_coverings  \
# 0   IfSymptomatic           NoMeasures           Strict
# 1   IfSymptomatic                  Ban           Strict
# 2   IfSymptomatic                Avoid           Strict
# 3   IfSymptomatic                  Ban           Strict
# 4   IfSymptomatic                  Ban      Recommended
#
#   international_travel_controls school_closures mortality
# 0                     Screening         Minimal       Low
# 1                    Quarantine            Some       Low
# 2                 BorderClosure            Some       Low
# 3                 BorderClosure        Required       Low
# 4                 BorderClosure            Some       Low
#
# [5 rows x 23 columns]

# %%
# See last 5 rows
covid.tail()
# Out:
#        location      continent    date  cases_per_M  deaths_per_M  \
# 520  Uzbekistan           Asia  Feb-21      228.539         0.358
# 521   Venezuela  South America  Feb-21     1569.633        19.482
# 522       Yemen           Asia  Feb-21       29.907         3.420
# 523      Zambia         Africa  Feb-21     3676.739        44.060
# 524    Zimbabwe         Africa  Feb-21     1788.679        82.823
#
#      stringency_index  population_density  median_age  aged_65_older  \
# 520             37.04              76.134        28.2          4.469
# 521             84.26              36.253        29.0          6.614
# 522             25.00              53.508        20.3          2.922
# 523             36.11              22.995        17.7          2.480
# 524             87.96              42.729        19.6          2.822
#
#      aged_70_older  ...  med_R  max_R  workplace_closures  contact_tracing  \
# 520          2.873  ...   0.93   1.23                Some    Comprehensive
# 521          3.915  ...   1.00   1.18              Strict             None
# 522          1.583  ...   1.09   1.72                None             None
# 523          1.542  ...   1.17   1.39              Strict    Comprehensive
# 524          1.882  ...   0.94   1.47                Some          Limited
#
#      testing_policy cancel_public_events facial_coverings  \
# 520   IfSymptomatic                Avoid           Strict
# 521          Public                  Ban           Strict
# 522            None           NoMeasures         NoPolicy
# 523   IfSymptomatic                Avoid           Strict
# 524   IfSymptomatic                  Ban           Strict
#
#     international_travel_controls school_closures mortality
# 520                           Ban            Some       Low
# 521                 BorderClosure        Required       Low
# 522                 BorderClosure         Minimal       Low
# 523                    Quarantine            Some       Low
# 524                    Quarantine            Some      High
#
# [5 rows x 23 columns]

# %%
# Information about the dataframe. This to check that the columns and rows are complete, there is 525 rows and 23 columns. 
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   location                       525 non-null    object
#  1   continent                      525 non-null    object
#  2   date                           525 non-null    object
#  3   cases_per_M                    525 non-null    float64
#  4   deaths_per_M                   525 non-null    float64
#  5   stringency_index               525 non-null    float64
#  6   population_density             525 non-null    float64
#  7   median_age                     525 non-null    float64
#  8   aged_65_older                  525 non-null    float64
#  9   aged_70_older                  525 non-null    float64
#  10  gdp_per_capita                 525 non-null    float64
#  11  life_expectancy                525 non-null    float64
#  12  human_development_index        525 non-null    float64
#  13  med_R                          525 non-null    float64
#  14  max_R                          525 non-null    float64
#  15  workplace_closures             525 non-null    object
#  16  contact_tracing                525 non-null    object
#  17  testing_policy                 525 non-null    object
#  18  cancel_public_events           525 non-null    object
#  19  facial_coverings               525 non-null    object
#  20  international_travel_controls  525 non-null    object
#  21  school_closures                525 non-null    object
#  22  mortality                      525 non-null    object
# dtypes: float64(12), object(11)
# memory usage: 94.5+ KB

# %%
# Summary stats of all numeric columns. Below are the statitics of quantitative(numerical) data in the dataset.
covid.describe()
# Out:
#         cases_per_M  deaths_per_M  stringency_index  population_density  \
# count    525.000000    525.000000        525.000000          525.000000
# mean    7117.880067    134.289072         61.992114          209.748581
# std    11393.095144    227.239874         18.444780          720.683293
# min        2.076000      0.011000          8.330000            1.980000
# 25%      322.346000      5.510000         50.000000           36.253000
# 50%     1943.832000     28.204000         64.350000           81.721000
# 75%     8856.786000    153.240000         76.850000          147.674000
# max    83076.430000   1434.497000        100.000000         7915.731000
#
#        median_age  aged_65_older  aged_70_older  gdp_per_capita  \
# count  525.000000     525.000000     525.000000      525.000000
# mean    31.866286       9.621537       6.172638    21522.861310
# std      8.933426       6.490335       4.477462    20755.375754
# min     15.100000       1.144000       0.526000      661.240000
# 25%     25.200000       3.941000       2.361000     6171.884000
# 50%     31.600000       7.104000       4.455000    15524.995000
# 75%     40.300000      15.070000      10.129000    32415.132000
# max     48.200000      27.049000      18.493000   116935.600000
#
#        life_expectancy  human_development_index       med_R       max_R
# count       525.000000               525.000000  525.000000  525.000000
# mean         74.123848                 0.750067    1.039219    1.443829
# std           6.828642                 0.147850    0.220853    0.579495
# min          53.280000                 0.394000    0.000000    0.010000
# 25%          70.780000                 0.665000    0.950000    1.160000
# 50%          75.270000                 0.777000    1.050000    1.300000
# 75%          78.860000                 0.866000    1.150000    1.550000
# max          84.630000                 0.957000    1.800000    6.150000

# %% [markdown]
# # Statistics of individual variables:
# # 1.

# %%
#  I can use the 'describe' function to calculate the statistic of 'cases_per_M' column of the dataset.
covid[['cases_per_M']].describe()
# Out:
#         cases_per_M
# count    525.000000
# mean    7117.880067
# std    11393.095144
# min        2.076000
# 25%      322.346000
# 50%     1943.832000
# 75%     8856.786000
# max    83076.430000

# %%
# This script is used to get the median of the column 'cases_per_M' of the dataset.
covid[['cases_per_M']].median()
# Out:
# cases_per_M    1943.832
# dtype: float64

# %%
# As it is usual in programming there is multiple means to achieve set goals. Below are another way to calculate the 
# statistics of column 'cases_per_M' of the dataset.

print("Using pandas module functions")
print("  n = ", covid['cases_per_M'].count())
print("Measures of central location")
print("Mean = ", covid['cases_per_M'].mean())
print("Median = ", covid['cases_per_M'].median())

print("Measures of spread")
print("range = ", covid['cases_per_M'].max()-covid['cases_per_M'].min())
q = covid['cases_per_M'].quantile([0.25,0.5,0.75])
print("quartiles = ", q)
print("IQR = ", covid['cases_per_M'].quantile(0.75) - covid['cases_per_M'].quantile(0.25))
print("stdev = ", covid['cases_per_M'].std())
print("pop stdev = ", covid['cases_per_M'].std(ddof = 0))

# print("Measures of shape")
print("Skewness = ", covid['cases_per_M'].skew())
print("Excess kurtosis = ", covid['cases_per_M'].kurt())
# Out:
# Using pandas module functions
#   n =  525
# Measures of central location
# Mean =  7117.880066666669
# Median =  1943.832
# Measures of spread
# range =  83074.35399999999
# quartiles =  0.25     322.346
# 0.50    1943.832
# 0.75    8856.786
# Name: cases_per_M, dtype: float64
# IQR =  8534.44
# stdev =  11393.095143653863
# pop stdev =  11382.239404987053
# Skewness =  2.4961269965529684
# Excess kurtosis =  7.527139760950313

# %%
# Sort in descending order for cases_per_M
covid.sort_values(by="cases_per_M",
                               ascending=False)
# Out:
#       location continent    date  cases_per_M  deaths_per_M  stringency_index  \
# 421    Czechia    Europe  Feb-21    83076.430      1434.497             69.44
# 499   Slovenia    Europe  Feb-21    60455.561      1205.427             69.44
# 429    Estonia    Europe  Feb-21    56719.026       468.136             41.67
# 452     Israel      Asia  Feb-21    56092.623       366.932             57.41
# 465  Lithuania    Europe  Feb-21    53256.246      1027.076             66.67
# ..         ...       ...     ...          ...           ...               ...
# 387      Yemen      Asia  Nov-20        3.990         1.307             16.67
# 83     Myanmar      Asia  May-20        3.970         0.092             80.56
# 386    Vietnam      Asia  Nov-20        3.113         0.011             46.76
# 24       China      Asia  May-20        2.928         1.227             81.94
# 283      China      Asia  Nov-20        2.076         0.014             81.94
#
#      population_density  median_age  aged_65_older  aged_70_older  ...  med_R  \
# 421             137.176        43.3         19.027         11.580  ...  1.080
# 499             102.619        44.5         19.062         12.930  ...  0.970
# 429              31.033        42.7         19.452         13.491  ...  1.120
# 452             402.606        30.6         11.733          7.359  ...  1.000
# 465              45.135        43.5         19.002         13.778  ...  0.920
# ..                  ...         ...            ...            ...  ...    ...
# 387              53.508        20.3          2.922          1.583  ...  0.580
# 83               81.721        29.1          5.732          3.120  ...  0.525
# 386             308.127        32.6          7.150          4.718  ...  0.990
# 24              147.674        38.7         10.641          5.929  ...  0.755
# 283             147.674        38.7         10.641          5.929  ...  1.055
#
#      max_R  workplace_closures  contact_tracing  testing_policy  \
# 421   1.33                Some    Comprehensive   IfSymptomatic
# 499   1.11              Strict    Comprehensive   IfSymptomatic
# 429   1.24                None             None   IfSymptomatic
# 452   1.41              Strict    Comprehensive   IfSymptomatic
# 465   1.15              Strict    Comprehensive   IfSymptomatic
# ..     ...                 ...              ...             ...
# 387   0.81                None             None            None
# 83    0.77              Strict          Limited   IfSymptomatic
# 386   1.36              Strict    Comprehensive          Public
# 24    1.32              Strict    Comprehensive          Public
# 283   1.64              Strict    Comprehensive          Public
#
#     cancel_public_events facial_coverings international_travel_controls  \
# 421                Avoid           Strict                           Ban
# 499                  Ban      Recommended                    Quarantine
# 429           NoMeasures      Recommended                    Quarantine
# 452                  Ban           Strict                 BorderClosure
# 465                  Ban      Recommended                    Quarantine
# ..                   ...              ...                           ...
# 387           NoMeasures         NoPolicy                 BorderClosure
# 83                   Ban           Strict                           Ban
# 386                Avoid      Recommended                           Ban
# 24                   Ban      Recommended                           Ban
# 283                  Ban      Recommended                           Ban
#
#     school_closures mortality
# 421            Some      High
# 499            Some      High
# 429         Minimal      High
# 452            Some      High
# 465            Some      High
# ..              ...       ...
# 387         Minimal       Low
# 83         Required       Low
# 386        Required       Low
# 24         Required       Low
# 283        Required       Low
#
# [525 rows x 23 columns]

# %%
# Visualisations of 'cases_per_M'
covid['cases_per_M'].hist(bins = 40) 
plt.show() 
print("The Histogram of cases_per_M is Right-Skewed. As we can see the mean = 7117.88, Median = 1943.83 against Max = 83076.43. \nI can say that most countries has low cases of the desease.")

# Plot of location against 'cases_per_M'
covid.boxplot('cases_per_M') 
plt.show()

print("Distribution by cases_per_M is Right-Skewed. As we can see the mean = 7117.88, Median = 1943.83 against Max = 83076.43. \nI can say that most countries has low cases of the desease.")
print("\n\nI will further use log-scale graph to further examin the data, as the histogram and boxplot show most data squashed to one end")

covid['cases_per_M'].plot.hist(bins = 150).set_xscale("log")
plt.show()
covid['cases_per_M'].plot.box().set_yscale("log")
plt.show()
print("When it comes to showing details, Histogram is not very effective, so instead density plot is tried.")
covid['cases_per_M'].plot.density().set_xscale("log")
plt.show()
# Out:
# The Histogram of cases_per_M is Right-Skewed. As we can see the mean = 7117.88, Median = 1943.83 against Max = 83076.43.
# I can say that most countries has low cases of the desease.
# Distribution by cases_per_M is Right-Skewed. As we can see the mean = 7117.88, Median = 1943.83 against Max = 83076.43.
# I can say that most countries has low cases of the desease.
#
#
# I will further use log-scale graph to further examin the data, as the histogram and boxplot show most data squashed to one end
# When it comes to showing details, Histogram is not very effective, so instead density plot is tried.

# %% [markdown]
# The visualisations (histogram and boxplot) show the distribution is Right-Skewed, meaning that more countries of locations, have fewer covid cases (0 - 4000) per millions.
#
# Log-scale graph and density plot, we can see that majority of the countries have lower cases per million (caes_per_M).

# %% [markdown]
# # 2. The med_R

# %%
#  I can use the 'describe' function to calculate the statistic of 'med_R' column of the dataset.
covid[['med_R']].describe()
# Out:
#             med_R
# count  525.000000
# mean     1.039219
# std      0.220853
# min      0.000000
# 25%      0.950000
# 50%      1.050000
# 75%      1.150000
# max      1.800000

# %%
# This script is used to get the median of the column 'med_R' of the dataset.
covid[['med_R']].median()
# Out:
# med_R    1.05
# dtype: float64

# %%
# As it is usual in programming there is multiple means to achieve set goals. Below are another way to calculate the 
# statistics,  hIstogram and boxplot  of column 'med_R' of the dataset.
import matplotlib.pyplot as plt
print("Using pandas module functions")
print("  n = ", covid['med_R'].count())
print("Measures of central location")
print("Mean = ", covid['med_R'].mean())
print("Median = ", covid['med_R'].median())

print("Measures of spread")
print("range = ", covid['med_R'].max()-covid['med_R'].min())
q = covid['med_R'].quantile([0.25,0.5,0.75])
print("quartiles = ", q)
print("IQR = ", covid['med_R'].quantile(0.75) - covid['med_R'].quantile(0.25))
print("stdev = ", covid['med_R'].std())
print("pop stdev = ", covid['med_R'].std(ddof = 0))

# print("Measures of shape")
print("Skewness = ", covid['med_R'].skew())
print("Excess kurtosis = ", covid['med_R'].kurt())
# Out:
# Using pandas module functions
#   n =  525
# Measures of central location
# Mean =  1.0392190476190468
# Median =  1.05
# Measures of spread
# range =  1.8
# quartiles =  0.25    0.95
# 0.50    1.05
# 0.75    1.15
# Name: med_R, dtype: float64
# IQR =  0.19999999999999996
# stdev =  0.22085270128986442
# pop stdev =  0.2206422651284147
# Skewness =  -1.316562912322257
# Excess kurtosis =  5.021591227384064

# %%
# Sort in descending order for med_R
covid.sort_values(by="med_R",
                               ascending=False)
# Out:
#                 location      continent    date  cases_per_M  deaths_per_M  \
# 84                 Nepal           Asia  May-20       53.918         0.241
# 74                Malawi         Africa  May-20       14.689         0.157
# 112           Tajikistan           Asia  May-20      410.479         4.718
# 94                  Peru  South America  May-20     4988.347       136.571
# 38              Ethiopia         Africa  May-20       10.186         0.079
# ..                   ...            ...     ...          ...           ...
# 7                Bahamas  North America  May-20      256.835        25.429
# 16                Brunei           Asia  May-20      320.012         2.286
# 116  Trinidad and Tobago  North America  May-20       82.173         5.001
# 147               Brunei           Asia  Aug-20        6.858         2.285
# 508           Tajikistan           Asia  Feb-21      116.800         0.419
#
#      stringency_index  population_density  median_age  aged_65_older  \
# 84              92.59             204.430        25.0          5.809
# 74              60.19             197.519        18.1          2.979
# 112             44.44              64.281        23.3          3.466
# 94              89.81              25.129        29.1          7.151
# 38              80.56             104.957        19.8          3.526
# ..                ...                 ...         ...            ...
# 7               92.59              39.497        34.3          8.996
# 16              52.78              81.347        32.4          4.591
# 116             87.04             266.886        36.2         10.014
# 147             40.74              81.347        32.4          4.591
# 508             16.67              64.281        23.3          3.466
#
#      aged_70_older  ...  med_R  max_R  workplace_closures  contact_tracing  \
# 84           3.212  ...  1.800   1.87                Some    Comprehensive
# 74           1.783  ...  1.565   1.61                Some    Comprehensive
# 112          2.155  ...  1.555   3.28                None          Limited
# 94           4.455  ...  1.550   1.83              Strict    Comprehensive
# 38           2.063  ...  1.550   2.45                Some          Limited
# ..             ...  ...    ...    ...                 ...              ...
# 7            5.200  ...  0.110   0.11              Strict    Comprehensive
# 16           2.382  ...  0.085   0.20                None          Limited
# 116          5.819  ...  0.050   0.15              Strict    Comprehensive
# 147          2.382  ...  0.000   0.01                None          Limited
# 508          2.155  ...  0.000   1.20                None          Limited
#
#      testing_policy cancel_public_events facial_coverings  \
# 84    IfSymptomatic                  Ban         NoPolicy
# 74    IfSymptomatic                  Ban      Recommended
# 112   IfSymptomatic                  Ban           Strict
# 94    IfSymptomatic                  Ban           Strict
# 38    IfSymptomatic                  Ban           Strict
# ..              ...                  ...              ...
# 7     IfSymptomatic                  Ban           Strict
# 16    IfSymptomatic                Avoid      Recommended
# 116   IfSymptomatic                  Ban      Recommended
# 147   IfSymptomatic                Avoid      Recommended
# 508   IfSymptomatic                  Ban           Strict
#
#     international_travel_controls school_closures mortality
# 84                            Ban        Required       Low
# 74                     Quarantine            Some       Low
# 112                           Ban         Minimal       Low
# 94                            Ban        Required      High
# 38                     Quarantine        Required       Low
# ..                            ...             ...       ...
# 7                       Screening        Required       Low
# 16                            Ban         Minimal       Low
# 116                 BorderClosure        Required       Low
# 147                           Ban         Minimal       Low
# 508                           Ban         Minimal       Low
#
# [525 rows x 23 columns]

# %%
# Visualisations of 'med_R'
covid['med_R'].hist(bins = 20) 
plt.show() 

# Plot of location against 'med_R'
covid.boxplot('med_R') 
plt.show()

# %% [markdown]
# The visualisations (histogram and boxplot) show the distribution is fairly. The Mean = 1.04 and Median = 1.05 are close the middle of the distribution, with regards to the max = 1.80 and min = 0.00. However, we can see outliers at both ends of the distribution, even when most of the data are concentrated in the middle - normal distribution, with stdev =  0.22,
# pop stdev =  0.22, Skewness =  -1.31 and Excess kurtosis =  5.02.
#
# The median of R-number (med_R) is fairly uniform distributed, with slight skew to the left.

# %% [markdown]
# # 3. The mortality

# %%
# Statistics and distribution  analysis by mortality using bar cahrt and pie chart

covid['mortality'].value_counts().plot.pie(autopct = '%1.1f')
plt.show()
covid['mortality'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# Distribution by mortality is lower by 15.8 and stands at 57.9, with more than half of the location with lower mortality.

# %%
## statistics, histogram and boxplot of the 'mortality' attribute of the covid cases
print("n = ", covid['mortality'].count())

# we can count the number of occurences in each category
counts = covid['mortality'].value_counts()
print(counts)
print("Measures of central category")
print("mode = ", covid['mortality'].mode())
# Out:
# n =  525
# Low     304
# High    221
# Name: mortality, dtype: int64
# Measures of central category
# mode =  0    Low
# dtype: object

# %%
# Getting the statistics of qualitative data like 'mortality'
covid[['mortality']].describe()
# Out:
#        mortality
# count        525
# unique         2
# top          Low
# freq         304

# %% [markdown]
# As a qualitative data 'mortality' has very few basic statistics as shown above.

# %% [markdown]
# # 4. The international_travel_controls

# %%
# distribution analysis by international_travel_controls
covid['international_travel_controls'].value_counts().plot.pie(autopct = '%1.1f')
plt.show()
covid['international_travel_controls'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# Distribution by international_travel_controls is imbalanced, as more than 50% of the locations are on the banned list. The government is using ban as the most tool to control spread of covid from other countries.

# %%
## statistics, histogram and boxplot of the 'international_travel_controls' attribute of the covid prevention
print("n = ", covid['international_travel_controls'].count())

# we can count the number of occurences in each category 
counts = covid['international_travel_controls'].value_counts()
print(counts)
print("Measures of central category")
print("mode = ", covid['international_travel_controls'].mode())
# Out:
# n =  525
# Ban              264
# Quarantine       152
# BorderClosure     54
# Screening         51
# None               4
# Name: international_travel_controls, dtype: int64
# Measures of central category
# mode =  0    Ban
# dtype: object

# %%
# Getting the statistics of qualitative data like 'international_travel_controls'
covid[['international_travel_controls']].describe()
# Out:
#        international_travel_controls
# count                            525
# unique                             5
# top                              Ban
# freq                             264

# %% [markdown]
# As a qualitative data 'international_travel_controls' has very few basic statistics as shown above.

# %% [markdown]
# # 5 The Cancel_public_events

# %%
## statistics, histogram and boxplot of the 'cancel_public_events' attribute of the covid prevention
print("n = ", covid['cancel_public_events'].count())

# we can count the number of occurences in each category 
counts = covid['cancel_public_events'].value_counts()
print(counts)
print("Measures of central category")
print("mode = ", covid['cancel_public_events'].mode())
# Out:
# n =  525
# Ban           391
# Avoid          89
# NoMeasures     45
# Name: cancel_public_events, dtype: int64
# Measures of central category
# mode =  0    Ban
# dtype: object

# %%
# Getting the statistics of qualitative data like 'cancel_public_events'
covid[['cancel_public_events']].describe()
# Out:
#        cancel_public_events
# count                   525
# unique                    3
# top                     Ban
# freq                    391

# %%
covid['cancel_public_events'].value_counts().plot.bar()
plt.show()
covid['cancel_public_events'].value_counts().plot.pie(autopct = '%1.1f')
plt.show()
covid['cancel_public_events'].value_counts().plot.bar().set_yscale("log")
plt.show()
print("High percentatage (74.5%) of public events were banned, so this is an imbalanced distribution,")
print("with most of the country favouring the ban of public events, as a way to minimise spread of the virus.")
print("However, there are still plenty of data available to indicate that most people choose to avoid public events.")
# Out:
# High percentatage (74.5%) of public events were banned, so this is an imbalanced distribution,
# with most of the country favouring the ban of public events, as a way to minimise spread of the virus.
# However, there are still plenty of data available to indicate that most people choose to avoid public events.

# %% [markdown]
# # Filtering data:

# %% [markdown]
# # 6. How the distribution of the cases_per_M varies with the value of continent

# %%
# distribution analysis of cases_per_M by continent
covid.hist('cases_per_M', by =  'continent', alpha = 0.9, edgecolor = "black", bins = 30, figsize = (15,5))
plt.show()
print()
covid.groupby('continent')['cases_per_M'].hist(alpha = 0.9, edgecolor = "black", bins = 30, figsize = (15,5))
plt.show()
covid.boxplot('cases_per_M', by = 'continent')
plt.show()
print("The distribution of infection cases by continent follows same pattern, but Europe has largerest cases followed by South America")
print("The distribution also, shows that countries in the Oceania have least cases_per_M, followed by countries of Africa. ")
# Out:
# The distribution of infection cases by continent follows same pattern, but Europe has largerest cases followed by South America
# The distribution also, shows that countries in the Oceania have least cases_per_M, followed by countries of Africa.

# %% [markdown]
# # 7. The statistics of the cases_per_M variable of the countries from Europe over the four 3-month periods ending May-20, Aug-20, Nov-20 and Feb-21

# %%
print("Using pandas module functions")
print("  n = ", covid['cases_per_M'].count())
print("Measures of central location")
print("Mean = ", covid['cases_per_M'].mean())
print("Median = ", covid['cases_per_M'].median())

print("Measures of spread")
print("range = ", covid['cases_per_M'].max()-covid['cases_per_M'].min())
q = covid['cases_per_M'].quantile([0.25,0.5,0.75])
print("quartiles = ", q)
print("IQR = ", covid['cases_per_M'].quantile(0.75) - covid['cases_per_M'].quantile(0.25))
print("stdev = ", covid['cases_per_M'].std())
print("pop stdev = ", covid['cases_per_M'].std(ddof = 0))

# print("Measures of shape")
print("Skewness = ", covid['cases_per_M'].skew())
print("Excess kurtosis = ", covid['cases_per_M'].kurt())
plt.show()
# Out:
# Using pandas module functions
#   n =  525
# Measures of central location
# Mean =  7117.880066666669
# Median =  1943.832
# Measures of spread
# range =  83074.35399999999
# quartiles =  0.25     322.346
# 0.50    1943.832
# 0.75    8856.786
# Name: cases_per_M, dtype: float64
# IQR =  8534.44
# stdev =  11393.095143653863
# pop stdev =  11382.239404987053
# Skewness =  2.4961269965529684
# Excess kurtosis =  7.527139760950313

# %%
covid.corr()
# Out:
#                          cases_per_M  deaths_per_M  stringency_index  \
# cases_per_M                 1.000000      0.803875          0.164149
# deaths_per_M                0.803875      1.000000          0.191140
# stringency_index            0.164149      0.191140          1.000000
# population_density          0.002547     -0.056312         -0.015501
# median_age                  0.379134      0.381945          0.056481
# aged_65_older               0.351715      0.396248         -0.031134
# aged_70_older               0.353229      0.398317         -0.033898
# gdp_per_capita              0.308022      0.170603          0.041747
# life_expectancy             0.363817      0.319357          0.152763
# human_development_index     0.393303      0.343858          0.142654
# med_R                       0.083916      0.014510          0.295182
# max_R                      -0.056270      0.012798          0.176519
#
#                          population_density  median_age  aged_65_older  \
# cases_per_M                        0.002547    0.379134       0.351715
# deaths_per_M                      -0.056312    0.381945       0.396248
# stringency_index                  -0.015501    0.056481      -0.031134
# population_density                 1.000000    0.134898       0.055507
# median_age                         0.134898    1.000000       0.912010
# aged_65_older                      0.055507    0.912010       1.000000
# aged_70_older                      0.024416    0.899439       0.994535
# gdp_per_capita                     0.295373    0.617644       0.458617
# life_expectancy                    0.169667    0.849529       0.729346
# human_development_index            0.140923    0.891746       0.762690
# med_R                             -0.011833    0.055794       0.064221
# max_R                              0.026420    0.246204       0.227238
#
#                          aged_70_older  gdp_per_capita  life_expectancy  \
# cases_per_M                   0.353229        0.308022         0.363817
# deaths_per_M                  0.398317        0.170603         0.319357
# stringency_index             -0.033898        0.041747         0.152763
# population_density            0.024416        0.295373         0.169667
# median_age                    0.899439        0.617644         0.849529
# aged_65_older                 0.994535        0.458617         0.729346
# aged_70_older                 1.000000        0.445886         0.713217
# gdp_per_capita                0.445886        1.000000         0.685517
# life_expectancy               0.713217        0.685517         1.000000
# human_development_index       0.747633        0.748027         0.923736
# med_R                         0.070406       -0.019369         0.062419
# max_R                         0.223910        0.204615         0.261743
#
#                          human_development_index     med_R     max_R
# cases_per_M                             0.393303  0.083916 -0.056270
# deaths_per_M                            0.343858  0.014510  0.012798
# stringency_index                        0.142654  0.295182  0.176519
# population_density                      0.140923 -0.011833  0.026420
# median_age                              0.891746  0.055794  0.246204
# aged_65_older                           0.762690  0.064221  0.227238
# aged_70_older                           0.747633  0.070406  0.223910
# gdp_per_capita                          0.748027 -0.019369  0.204615
# life_expectancy                         0.923736  0.062419  0.261743
# human_development_index                 1.000000  0.064193  0.267866
# med_R                                   0.064193  1.000000  0.350317
# max_R                                   0.267866  0.350317  1.000000

# %%
import seaborn
tempEuropeCovid = covid.loc[(covid['continent'] =='Europe')]
tempEuropeCovid

#seaborn.pairplot(europe)
#plt.show()
# Out:
#                    location continent    date  cases_per_M  deaths_per_M  \
# 1                   Albania    Europe  May-20      394.398        11.120
# 5                   Austria    Europe  May-20     1856.125        74.058
# 10                  Belarus    Europe  May-20     4503.498        24.764
# 11                  Belgium    Europe  May-20     5037.181       816.593
# 14   Bosnia and Herzegovina    Europe  May-20      764.444        46.330
# ..                      ...       ...     ...          ...           ...
# 502                   Spain    Europe  Feb-21    33287.375       588.090
# 506                  Sweden    Europe  Feb-21    47742.065       642.720
# 507             Switzerland    Europe  Feb-21    28676.136       616.088
# 515                 Ukraine    Europe  Feb-21    17703.760       400.332
# 517          United Kingdom    Europe  Feb-21    39013.446       992.575
#
#      stringency_index  population_density  median_age  aged_65_older  \
# 1               86.11             104.871        38.0         13.188
# 5               53.70             106.749        44.4         19.202
# 10              16.67              46.858        40.3         14.799
# 11              75.00             375.564        41.8         18.571
# 14              65.74              68.496        42.5         16.569
# ..                ...                 ...         ...            ...
# 502             71.30              93.105        45.5         19.436
# 506             69.44              24.718        41.0         19.985
# 507             60.19             214.243        43.1         18.436
# 515             60.19              77.390        41.4         16.462
# 517             86.11             272.898        40.8         18.517
#
#      aged_70_older  ...  med_R  max_R  workplace_closures  contact_tracing  \
# 1            8.643  ...  1.040   1.45              Strict    Comprehensive
# 5           13.748  ...  0.820   3.06              Strict    Comprehensive
# 10           9.788  ...  1.325   2.37                None    Comprehensive
# 11          12.849  ...  0.985   2.60              Strict    Comprehensive
# 14          10.711  ...  1.150   1.17                Some             None
# ..             ...  ...    ...    ...                 ...              ...
# 502         13.799  ...  1.020   1.35              Strict          Limited
# 506         13.433  ...  1.190   1.26                Some          Limited
# 507         12.644  ...  0.960   1.05              Strict    Comprehensive
# 515         11.133  ...  0.930   1.29              Strict    Comprehensive
# 517         12.527  ...  0.840   1.63              Strict          Limited
#
#      testing_policy cancel_public_events facial_coverings  \
# 1     IfSymptomatic                  Ban           Strict
# 5            Public                  Ban      Recommended
# 10           Public                Avoid      Recommended
# 11    IfSymptomatic                  Ban           Strict
# 14    IfSymptomatic                  Ban           Strict
# ..              ...                  ...              ...
# 502   IfSymptomatic                  Ban           Strict
# 506   IfSymptomatic                  Ban         NoPolicy
# 507   IfSymptomatic                  Ban      Recommended
# 515   IfSymptomatic                Avoid           Strict
# 517   IfSymptomatic                  Ban      Recommended
#
#     international_travel_controls school_closures mortality
# 1                      Quarantine            Some       Low
# 5                             Ban         Minimal      High
# 10                     Quarantine         Minimal       Low
# 11                            Ban         Minimal      High
# 14                      Screening            Some       Low
# ..                            ...             ...       ...
# 502                           Ban            Some      High
# 506                           Ban            Some      High
# 507                           Ban         Minimal      High
# 515                    Quarantine        Required      High
# 517                    Quarantine        Required      High
#
# [147 rows x 23 columns]

# %%
europeCovid = tempEuropeCovid[['cases_per_M', 'location', 'date']]
europeCovid
# Out:
#      cases_per_M                location    date
# 1        394.398                 Albania  May-20
# 5       1856.125                 Austria  May-20
# 10      4503.498                 Belarus  May-20
# 11      5037.181                 Belgium  May-20
# 14       764.444  Bosnia and Herzegovina  May-20
# ..           ...                     ...     ...
# 502    33287.375                   Spain  Feb-21
# 506    47742.065                  Sweden  Feb-21
# 507    28676.136             Switzerland  Feb-21
# 515    17703.760                 Ukraine  Feb-21
# 517    39013.446          United Kingdom  Feb-21
#
# [147 rows x 3 columns]

# %%
# Statistics of Cases_per_M in Europe.
europeCovid.describe()
# Out:
#         cases_per_M
# count    147.000000
# mean   13718.374891
# std    15752.497741
# min      174.955000
# 25%     1492.503500
# 50%     6246.246000
# 75%    22788.934000
# max    83076.430000

# %%
print("Using pandas module functions")
print("  n = ", europeCovid['cases_per_M'].count())
print("Measures of central location")
print("Mean = ", europeCovid['cases_per_M'].mean())
print("Median = ", europeCovid['cases_per_M'].median())

print("Measures of spread")
print("range = ", europeCovid['cases_per_M'].max()-europeCovid['cases_per_M'].min())
q = europeCovid['cases_per_M'].quantile([0.25,0.5,0.75])
print("quartiles = ", q)
print("IQR = ", europeCovid['cases_per_M'].quantile(0.75) - europeCovid['cases_per_M'].quantile(0.25))
print("stdev = ", europeCovid['cases_per_M'].std())
print("pop stdev = ", europeCovid['cases_per_M'].std(ddof = 0))

print("Using pandas module functions")
print("  n = ", europeCovid['cases_per_M'].count())
print("Measures of central location")
print("Mean = ", europeCovid['cases_per_M'].mean())
print("Median = ", europeCovid['cases_per_M'].median())
# Out:
# Using pandas module functions
#   n =  147
# Measures of central location
# Mean =  13718.374891156463
# Median =  6246.246
# Measures of spread
# range =  82901.47499999999
# quartiles =  0.25     1492.5035
# 0.50     6246.2460
# 0.75    22788.9340
# Name: cases_per_M, dtype: float64
# IQR =  21296.430500000002
# stdev =  15752.497740548053
# pop stdev =  15698.826382676314
# Skewness =  1.458812359936426
# Excess kurtosis =  2.2119138922869

# %%
ct2 = pd.crosstab(europeCovid['location'],europeCovid['date'], values = europeCovid['cases_per_M'], aggfunc = 'mean')
fig, ax = plt.subplots(1, 1, figsize=(30, 8))
europeCovid['date']= pd.Categorical(europeCovid['date'], categories=['May-20','Aug-20','Nov-20','Feb-21'])
ct2.plot.bar(stacked=True, ax=ax)
plt.show()
import warnings
warnings.simplefilter('ignore')
# Out:
# <ipython-input-38-ccb8a14c6e62>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   europeCovid['date']= pd.Categorical(europeCovid['date'], categories=['May-20','Aug-20','Nov-20','Feb-21'])

# %%
##### # distribution analysis of cases_per_M by continent
plt.subplots = covid.hist('cases_per_M', by =  'date', alpha = 0.9, color = "Purple" , edgecolor = "black", bins = 20, figsize = (15,5))
plt .ylabel ("cases_per_m")
plt.xlabel ("date")
covid.boxplot("cases_per_M", by = "date" , vert = False)
plt.show()
covid.describe()
plt.show()
covid.groupby('date')['cases_per_M'].hist(alpha = 0.5, edgecolor = "black", bins = 20, figsize = (15,5))
plt.show()


covid['cases_per_M'].plot.density().set_xscale("log")
plt.show()


covid.boxplot('cases_per_M', by = 'date')
plt.show()

# %% [markdown]
# # 8. Creating cross-tabulations in the form of two-way tables using Mortality versus date

# %%
# cross-tabulate Mortality Versus Date
ct2 = pd.crosstab(covid['mortality'], covid['date'])
ct2
# Out:
# date       Aug-20  Feb-21  May-20  Nov-20
# mortality
# High           38      82      30      71
# Low            92      53      99      60

# %%
# Using cross-tabulate Mortality Versus Date to create informative bar charts

ct1 = pd.crosstab(covid['mortality'], covid['date'])
fig,ax = plt.subplots(1,2,figsize = (10, 4))
ct1.plot.bar (ax=ax[0])
ct1.plot.bar(stacked = True, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='mortality'>

# %%
# Using cross-tabulate Mortality Versus Date to create informative bar charts

ct1 = pd.crosstab(covid['mortality'], covid['date'])
fig,ax = plt.subplots(1,2,figsize = (10, 4))
ct1.plot.bar (ax=ax[0])
ct1.plot.bar(stacked = True, ax=ax[1])

# %% [markdown]
# # Task 12. To check for missing values and remove any missing value .

# %%
# load and summarize the dataset

import pandas as pd # Importing pandas library
import matplotlib.pyplot as plt
covid = pd.read_csv (r"C:\Users\chinw\Downloads\covid.csv", header=None) # loading dataset
covid
# summarize the dataset
print(dataset.describe())

# replace '0' values with 'nan'
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# count the number of nan values in each column
print(dataset.isnull().sum())

# example of removing rows that contain missing values
import pandas as pd # Importing pandas library
import matplotlib.pyplot as plt
covid = pd.read_csv (r"C:\Users\chinw\Downloads\covid.csv", header=None) # loading dataset
covid
# summarize the shape of the raw data
print(dataset.shape)
# replace '0' values with 'nan'
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# drop rows with missing values
dataset.dropna(inplace=True)
# summarize the shape of the data with missing rows removed
print(dataset.shape)
